# %% [markdown]
# ### 📚  6강_배경지식 퀴즈

# %% [markdown]
# ※ 이 자료는 헤이밥 코딩테스트 강의를 위한 자료입니다.
# 수강생들만을 위한 자료로, 무단 배포를 금합니다.

# %% [markdown]
# ### **배경지식 예제**
# **쇼핑 할인 쿠폰 선택: 그리디 접근법**
#
# #### 상황 설명:
# 온라인 쇼핑몰에서 구매하려는 물건이 총 7종류 있으며, 각 물건의 가격은 1만원부터 10만원까지 다양합니다. 할인 쿠폰은 10%, 15%, 20%, 25%, 30%의 다섯 종류가 있으며, 각 쿠폰은 한 번씩만 사용할 수 있습니다. 쿠폰을 사용하여 전체 구매 비용을 최소화하려 합니다.
#
# #### 그리디 선택:
# **쿠폰과 물건의 매칭 방법**: #TODO 1
#
# #### 그리디 알고리즘의 핵심 적용:
# - **매 순간의 최적 선택**:  #TODO 2
# - **전체 목표 달성**: #TODO 3
#
# 그리디 알고리즘의 특성인 매 순간 최적의 선택을 통해 전체적인 목표를 달성하는 방법론을 적용하여, 이 문제를 어떻게 해결할지 간단하게 생각을 정리해 보시면 됩니다!

# %%
# TODO1       가장 비싼 물건에 가장 할인율 큰 쿠폰 적용
# TODO2       현재 상태에서 남아있는 물건 중 가장 비싼 물건에, 현재 남아있는 쿠폰 중 가장 할인율 큰 쿠폰 적용 (물건-쿠폰 매칭 후 이 쌍은 제거)
# TODO3       전체 구매 비용 최소화

# %% [markdown]
# 이제 위의 문제를 코딩으로 해결해봅시다!
#
# #### **쇼핑 할인 쿠폰 최적 활용 코드**
#
# #### 문제 설명:
# 온라인 쇼핑몰에서 여러 종류의 물건을 구매하려고 합니다. 각 물건의 가격과 사용 가능한 할인 쿠폰이 주어졌을 때, 쿠폰을 최적으로 활용하여 전체 구매 비용을 최소화하는 프로그램을 작성하세요.
#
# - 물건의 가격과 할인 쿠폰의 할인율이 각각 리스트로 주어집니다.
# - 각 쿠폰은 한 번씩만 사용할 수 있으며, 한 물건에만 적용됩니다.
# - 모든 물건은 반드시 구매해야 하며, 모든 쿠폰을 사용해야 합니다.
#
# #### 입력:
# - `prices`: 물건의 가격이 담긴 리스트 (예: `[10000, 20000, 30000, 40000, 50000, 60000, 70000]`)
# - `discounts`: 할인율이 담긴 리스트 (예: `[10, 15, 20, 25, 30]`)
#
# #### 출력:
# - 할인 쿠폰을 최적으로 활용했을 때의 최소 전체 구매 비용
#
# #### 함수 형태:
# ```python
# def minimum_total_cost(prices: list, discounts: list) -> int:
#     pass
# ```
#
# #### 입출력 예시:
# #### 예시 1:
# - 입력: `prices = [10000, 20000, 30000, 40000, 50000, 60000, 70000]`, `discounts = [10, 15, 20, 25, 30]`
#
# - 70000원짜리 물건에 30% 할인 적용: $70000 \times (1 - 0.3) = 49000$
# - 60000원짜리 물건에 25% 할인 적용: $60000 \times (1 - 0.25) = 45000$
# - 50000원짜리 물건에 20% 할인 적용: $50000 \times (1 - 0.2) = 40000$
# - 40000원짜리 물건에 15% 할인 적용: $40000 \times (1 - 0.15) = 34000$
# - 30000원짜리 물건에 10% 할인 적용: $30000 \times (1 - 0.1) = 27000$
# - 나머지 물건들인 20000원과 10000원짜리 물건에는 할인을 적용할 수 없으므로, 그 가격 그대로 계산합니다.
#
# 최종 합산:  $49000 + 45000 + 40000 + 34000 + 27000 + 20000 + 10000 = 252000$원
#
# #### 예시 2:
# - 입력: `prices = [15000, 30000, 20000]`, `discounts = [10, 20]`
#
# - 30000원짜리 물건에 20% 할인 적용: $30000 \times (1 - 0.2) = 24000$
# - 20000원짜리 물건에 10% 할인 적용: $20000 \times (1 - 0.1) = 18000$
# - 15000원짜리 물건에는 할인을 적용할 수 없으므로, 그 가격 그대로 계산합니다.
#
# 최종 합산:  $24000 + 18000 + 15000 = 57000$원
#
# #### 예시 3:
# - 입력: `prices = [5000, 10000, 15000]`, `discounts = [5, 10]`
#
# - 15000원짜리 물건에 10% 할인 적용: $15000 \times (1 - 0.1) = 13500$
# - 10000원짜리 물건에 5% 할인 적용: $10000 \times (1 - 0.05) = 9500$
# - 5000원짜리 물건에는 할인을 적용할 수 없으므로, 그 가격 그대로 계산합니다.
#
# 최종 합산:  $13500 + 9500 + 7500 = 30500$원

# %%
#예제 1 코드 (빈칸 채우기)

def minimum_total_cost(prices: list, discounts: list) -> int:
    # 물건의 가격과 할인율을 내림차순으로 정렬
    prices.sort(reverse=True)
    discounts.sort(reverse=True)

    # 할인율이 적용된 가격 계산
    discounted_prices = []
    for i in range(len(prices)):
        if i < len(discounts):
             #TODO
        else:
            #TODO
        discounted_prices.append(discounted_price)

    # 최소 전체 구매 비용 반환
    return int(sum(discounted_prices))

# 입출력 예시
example1 = minimum_total_cost([10000, 20000, 30000, 40000, 50000, 60000, 70000], [10, 15, 20, 25, 30])
example2 = minimum_total_cost([15000, 30000, 20000], [10, 20])
example3 = minimum_total_cost([5000, 10000, 15000], [5, 10])
# example4 # TODO: 추가적인 입출력 예시 하나를 종이와 펜으로 만들어봅시다 (직접 예시를 만들기)
example4 = minimum_total_cost([10000, 20000], [5, 10, 10]) #20000 * 0.9 + 10000*0.9 = 27000 원 결제

example1, example2, example3, example4

# %% [markdown]
# ### 배경지식 예제 예시 답안 코드

# %%
#모범답안 코드

def minimum_total_cost(prices: list, discounts: list) -> int:
    # 물건의 가격과 할인율을 내림차순으로 정렬
    prices.sort(reverse=True)
    discounts.sort(reverse=True)

    # 할인율이 적용된 가격 계산
    discounted_prices = []
    for i in range(len(prices)):
        if i < len(discounts):
            discounted_price = prices[i] * (1 - discounts[i] / 100) #TODO
        else:
            discounted_price =  prices[i] #TODO
        discounted_prices.append(discounted_price)

    # 최소 전체 구매 비용 반환
    return int(sum(discounted_prices))

# 입출력 예시
example1 = minimum_total_cost([10000, 20000, 30000, 40000, 50000, 60000, 70000], [10, 15, 20, 25, 30])
example2 = minimum_total_cost([15000, 30000, 20000], [10, 20])
example3 = minimum_total_cost([5000, 10000, 15000], [5, 10])
# example4 # TODO: 추가적인 입출력 예시 하나를 종이와 펜으로 만들어봅시다 (직접 예시를 만들기)
example4 = minimum_total_cost([10000, 20000], [5, 10, 10]) #20000 * 0.9 + 10000*0.9 = 27000 원 결제

example1, example2, example3, example4
